# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset =pd.read_csv('housing.csv')

# %%
dataset.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0     -122.23     37.88                41.0        880.0           129.0  \
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# ...

# %%
dataset.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms
# count  20640.000000  20640.000000        20640.000000  20640.000000  \
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    20433.000000  20640.000000  20640.000000   20640.000000  \
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# informations about the non numerical attribute in the dataset  
dataset['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
dataset.hist(bins=50 , figsize=(20,15))
plt.show()

# %%
dataset.plot(kind ="scatter", x="longitude", y="latitude")
dataset.plot(kind="scatter", x="median_income", y="median_house_value")
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
from sklearn.model_selection import train_test_split 
train_set , test_set = train_test_split(dataset , test_size =0.2 , random_state=42)

# %%
print(f"the train set len is : {len(train_set)}")
print(f"the test set len is : {len(test_set)}")
# Out:
# the train set len is : 16512
# the test set len is : 4128

# %%
data = dataset.drop("median_house_value" , axis=1)
data_labels = dataset['median_house_value']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.4+ MB

# %%
data_numerical  = train_set.drop("ocean_proximity", axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.impute import SimpleImputer
num_pipeline = Pipeline([
('imputer', SimpleImputer(strategy="median")),
('std_scaler', StandardScaler()),
])

# %%
data_numerical  = data.drop("ocean_proximity", axis=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
num = list(data_numerical)
cat = ["ocean_proximity"]
my_pipeline = ColumnTransformer([
("num", num_pipeline, num),
("cat", OneHotEncoder(), cat),
])
data_fin = my_pipeline.fit_transform(data)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(data_fin, data_labels)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
predictions = regressor.predict(data_fin)
linear_reg_mse = mean_squared_error(data_labels, predictions)
linear_reg_rmse = np.sqrt(linear_reg_mse)
linear_reg_rmse
# Out:
# 68709.3255776217

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor()
rf_reg.fit(data_fin, data_labels)
rf_predictions = rf_reg.predict(data_fin)
rf_mse = mean_squared_error(data_labels, rf_predictions)
rf_rmse = np.sqrt(rf_mse)
rf_rmse
# Out:
# 17978.94789939077

# %%
from sklearn.model_selection import cross_val_score
rf_scores = cross_val_score(forest_reg, data_fin, data_labels,
scoring="neg_mean_squared_error", cv=10)
randomForest_rmse_scores = np.sqrt(-scores)

# %%
randomForest_rmse_scores.mean()
# Out:
# 48416.076874924474
